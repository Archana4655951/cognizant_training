# %%
print("Broad Casting")
# Out:
# Broad Casting

# %%
import numpy as np
a = np.array([1,2,3,4])
print(a + 5)
# Out:
# [6 7 8 9]

# %%
import numpy as np
b = np.array([3,8,7,9])
print(b*5)
# Out:
# [15 40 35 45]

# %%
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])

print(a + b)
# Out:
# [5 7 9]

# %%
import numpy as np 
s = np.array([2,4,6])
print(s/2)
# Out:
# [1. 2. 3.]

# %%
import numpy as np
a = np.array([[1,2],
              [3,4]])
print(a + 10)
# Out:
# [[11 12]
#  [13 14]]

# %%
import numpy as np
arr = np.array([10])
print(arr[::2])
# Out:
# [10]

# %%
import numpy as np
a = np.array([[1,2,3],
              [4,5,6]])
b = np.array([1,1,1])
print(a+b)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
import numpy as np
a = np.array(["Python","Java","C","C++"])
print(a + "Language")
# Out:
# ['PythonLanguage' 'JavaLanguage' 'CLanguage' 'C++Language']
