# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello world")
# Out:
# Hello world

# %%
a=20
b=30
sum==("a+b")
print("
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 b=30
#       3 sum==("a+b")
# ----> 4 print(c)
#
# NameError: name 'c' is not defined
