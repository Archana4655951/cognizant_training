# %%
for i in range(1,5):
    print("I'm Archana")

# %%
marks = (75,70,67,80,92,83)
for m in marks:
   print(m)

# %%
marks = (80,90,70,60,50,40)
for m in marks:
    print(m)
    print(marks[0])

# %%
for i in range(1,11):
    print(i)

# %%
for i in range(2,21,2):
    print(i)

# %%
marks = [100,90,80,70,60,50]
for i in range(len(marks)):
    print(i)
