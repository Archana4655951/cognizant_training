# %%
def add (*numbers):
   print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def add (*numbers):
   print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add (10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def student(*marks):
    print(sum(marks))
student(40,30,50)
# Out:
# 120

# %%
def student(*marks):
    print(sum(marks))
student(40,30)
student(30,50,80)
student(30,30,40)
student(80,90,70,95,90)
student(50,50,50)
# Out:
# 70
# 160
# 100
# 425
# 150

# %%
def student(*marks):
    print(total(marks))
add(40,30)
add(30,50,80)
add(30,30,40)
add(80,90,70,95,90)
add(50,50,50)
# Out:
# 70
# 160
# 100
# 425
# 150

# %%
print(10+20)
print("Kavita"+"Yadav")
# Out:
# 30
# KavitaYadav

# %%
print(10000+300000)
print("sweety"+"narukulla")
# Out:
# 310000
# sweetynarukulla

# %%
class Student:
    def __init__ (self,marks):
        self.marks = marks

    def __add__(self,others):
        return self.marks+others.marks
s1 = Student(80)
s2 = Student(75)
print(s1+s2)
# Out:
# 155

# %%
name = "sweety"
print(name.upper())
# Out:
# SWEETY
