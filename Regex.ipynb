# %%
import re
text = "My Name is Archana"
x = re.search("Archana",text)
if x:
     print("Found")
# Out:
# Found

# %%
import re
sweety = "Archana.Narukulla7@gmail.com"
result = re.search(r"\d",sweety)

if result:
    print("Digit found")
else:
    print("no digit found")
# Out:
# Digit found

# %%
import re 
text = "I have 2 pens and 10 Books"
numbers = re.findall(r"\d+",text)
print(numbers)
# Out:
# ['2', '10']

# %%
import re
text= "I have 25 books"
numbers = re.findall(r"\d+",text)
print(numbers)
# Out:
# ['25']

# %%
import re 
phone_number = "9876543210"
if re.fullmatch(r"\d{10}" ,phone_number):
    print("Valid number")
else :
    print("Invalid number")
# Out:
# Valid number

# %%
import re
text = "Hello Archana"
newtext = re.sub(r"\s","-",text)
print(newtext)
# Out:
# Hello-Archana

# %%
import re
text = "Archana is a Good Girl"
result = re.findall(r"\w+",text)
print(result)
# Out:
# ['Archana', 'is', 'a', 'Good', 'Girl']

# %%
import re
text = " abc 123 def 456 ghi 789 jkl 0"
result = re.sub(r"\d","",text)
print (result)
# Out:
#  abc  def  ghi  jkl

# %%
import re
text = " abc 123 def 456 ghi 789 jkl 0"
result = re.sub(r"\W","",text)
print(result)
# Out:
# abc123def456ghi789jkl0

# %%
import re
text = "#python #java #c #c++ "
result = re.findall(r"#\w+",text)
print(result)
# Out:
# ['#python', '#java', '#c', '#c']
