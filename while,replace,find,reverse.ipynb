# %%
i=1 
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=5 
while i>=1:
    print(i)
    i-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
i = 1
while i<=8 :
    print(i*1)
    i +=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
S = "I like Python"
print(S.replace("Python","Java"))
# Out:
# I like Java

# %%
S = "archana is a good girl"
print(S.replace("good","GOOD"))
# Out:
# archana is a GOOD girl

# %%
K = "KARIMNAGAR"
print(K.replace("A","s"))
# Out:
# KsRIMNsGsR

# %%
s = " i love python"
print(s.replace("love","hate"))
# Out:
#  i hate python

# %%
s = "anything something"
print(s.find("something"))
# Out:
# 9

# %%
sweety = "I love Python"
print(sweety.find("Python"))
# Out:
# 7

# %%
import re
text = "I love to be in Alphores womens degree college"
result = re.findall("a",text)
print(result)
# Out:
# []

# %%
p = "python"
print(p[::-1])
# Out:
# nohtyp

# %%
s = "Alphores womens degree and pg college"
print(s[::-1])
# Out:
# egelloc gp dna eerged snemow serohplA

# %%
marks = [10,20,30,40,50,60,70,80,90]
marks.reverse()
print(marks)
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 10]
