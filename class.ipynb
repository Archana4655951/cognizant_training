# %%
class Student:
    name = "Sweety"

s = Student()
print(s.name)
# Out:
# Sweety

# %%
class Car:
    brand ="BMW"
    colour ="blue"
    price = "2Cr"

c = Car()
print(c.brand)
# Out:
# BMW

# %%
class Car1:
         brand = "BMW"
         colour = "blue"
         price = "2cr"

c1 = Car1()
print(c1.brand)
# Out:
# BMW

# %%
class Car:
    brand = "BMW"
    colour = "black"

car1 = Car()
car2 = Car()

print(car1.brand)
print(car2.colour)
# Out:
# BMW
# black

# %%
class Mybike:
    brand ="Royal Enfield"
    colour = "black"
    price = "2L" 
sweety = Mybike()
print(sweety)

# %%
class Student:
    student1 = "archana"
    student2 = "sweety"
    student3 = "xxxxx"
    student4 = "yyyyy"
student1 = Student()
student2 = Student()
student3 = Student()
student4 = Student()

print(student1)
print(student2)

# %%
class Student:
    def __init__(self,name,course):
       self.name = name
       self.course = course
s1 = Student("Sweety","BSc Data Science")

print (s1.name)
# Out:
# Sweety

# %%
class Student:
   def __init__(self,name,course):
       self.name = name
       self.course = course

s1 = Student("Sweety","BSc Data Science")
s2 = Student("Archana","BBA AI")
s3 = Student("Narukulla","YYYY")

print (s1.course)
print (s2.name)
print (s3.name)
# Out:
# BSc Data Science
# Archana
# XXXX

# %%
class Car:
    def __init__(self,brand,colour):
        self.brand = brand
        self.colour = colour

car1 = Car("lamborgini","green")
car2 = Car("BMW","navy blue")

print (car1.brand)
print (car2.colour)
# Out:
# lamborgini
# navy blue

# %%
class Student:
    name = "Sweety"

s = Student()
print(s.name)
# Out:
# Sweety

# %%
class Student:
    def __init__ (self,course,college,group) :
       self.course = course
       self.college = college
       self.group = group

s1 = Student("MStDs","awdc","bsc")
print(s1.course)
# Out:
# MStDs

# %%
class Student:
    def __init__ (self,marks):
        self.marks = marks

    def __add__(self,others):
        return self.marks+others.marks
s1 = Student(80)
s2 = Student(75)
print(s1+s2)
# Out:
# 155
