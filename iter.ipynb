# %%
name = ["archana","Sweety","1234"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# archana
# Sweety
# 1234

# %%
numbers = ["1234","5678","90"]
it=iter(numbers)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1234
# 5678
# 90

# %%
name = "Python"

it = iter(name)

print(next(it))
print(next(it))
print(next(it))
# Out:
# P
# y
# t

# %%
data = (1,2,3)

it = iter(data)

for i in it:
    print(i)
# Out:
# 1
# 2
# 3

# %%
fruits = ["Apple","Mango","banana"]
it = iter(fruits)

for item in it:
     print(item)
# Out:
# Apple
# Mango
# banana

# %%
numbers = [1,2,3]
it = iter(numbers)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3

# %%
it = iter(range(1,8))

print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3

# %%
it = iter([10,20,30,40,50])
print(list(it))
# Out:
# [10, 20, 30, 40, 50]

# %%
names = ["sweety","Archana","Narukulla"]
it = iter(names)

print(next(it))
# Out:
# sweety
