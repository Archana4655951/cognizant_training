# %%
print("Pandas")
# Out:
# Pandas

# %%
import pandas as pd
x = pd.Series()
print(x)
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
import numpy as np
sweety = np.array(['a','r','c','h','a','n','a'])
s = pd.Series(sweety)
print(s)
# Out:
# 0    a
# 1    r
# 2    c
# 3    h
# 4    a
# 5    n
# 6    a
# dtype: object

# %%
import pandas as pd
import numpy as np
sweety ={'x':0,'y':1,'z':2}
a = pd.Series
print(a)
# Out:
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd
marks=pd.Series([10,20,30,40,50,60])
mark=pd.Series()
print(marks)
print(mark)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64
# Series([], dtype: object)

# %%
import pandas as pd
students_name=pd.Series(["sweety","archana","archana"])
print(students_name)
# Out:
# 0     sweety
# 1    archana
# 2    archana
# dtype: object

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
student=pd.Series({"archana":10,"sweety":20,"narukulla":30})
print(student)
# Out:
# archana      10
# sweety       20
# narukulla    30
# dtype: int64

# %%
import pandas as pd
student=[{"sweety":12,"sravika":90,"pavitra":98}]
s=pd.Series(student)
print(student)
# Out:
# [{'sweety': 12, 'sravika': 90, 'pavitra': 98}]

# %%
import pandas as pd

i=pd.Series([10,20,30])
print(i)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd
a=pd.Series([100,200,300])
print(a[1])
# Out:
# 200

# %%
print("Deafult Index")
# Out:
# Deafult Index

# %%
i = pd.Series([10,20,30])
print(i)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
print("Custom Index")
# Out:
# Custom Index

# %%
import pandas as pd 
city = pd.Series([100,200,300,400,500],index = ["a","b","c","d","e"])
print(city)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
import pandas as pd
ci = pd.Series([10,20,30,40,50])
print(ci.index)
print(ci.values)
print(ci.dtype)
# Out:
# RangeIndex(start=0, stop=5, step=1)
# [10 20 30 40 50]
# int64

# %%
import pandas as pd
s = pd.Series ([10,20,30,40,50])
print(s.sum())
print(s.max())
print(s.min())
# Out:
# 150
# 50
# 10

# %%
import pandas as pd
subjects = {
    "Maths":95,
    "Science":90,
    "English":85
}
s = pd.Series(subjects)
print(s)
# Out:
# Maths      95
# Science    90
# English    85
# dtype: int64
