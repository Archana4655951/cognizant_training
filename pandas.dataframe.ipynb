# %%
print("DataFrame in Pandas")
# Out:
# DataFrame in Pandas

# %%
import pandas as pd
data = {
      "Name":["Archana","Sweety"]
}
D = pd.DataFrame(data)
print(data)
# Out:
# {'Name': ['Archana', 'Sweety']}

# %%
import pandas as pd
data = {
    "Name" :["Archana","Sweety"],
    "age" :[19,20]
}
D = pd.DataFrame(data)
print(data)
# Out:
# {'Name': ['Archana', 'Sweety'], 'age': [19, 20]}
