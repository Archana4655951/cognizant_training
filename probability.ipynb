# %%
import random
toss = random.choice(["Head","Tail"])
print(toss)
# Out:
# Head

# %%
a = 1
b = 6
p = a/b
print("Probability = ",p)
# Out:
# Probability =  0.16666666666666666

# %%
heads = 3894
total = 2634
probability = heads / total
print("Probability =",probability)
# Out:
# Probability = 1.4783599088838268

# %%
kings = 3
Queens = 4
cards = 52
probability = (kings+Queens)/cards
print("probability =",probability)
# Out:
# probability = 0.1346153846153846

# %%
odd = 3
total =6
probability = odd/total
print("Probability =",probability)
# Out:
# Probability = 0.5

# %%
black = 5
red = 7

probability = black/red/total
print("Probability = ",probability)
# Out:
# Probability =  0.11904761904761905

# %%
vowels =5
letters = 26
probability = vowels / letters
print("Probability =",probability)
# Out:
# Probability = 0.19230769230769232
