# %%
name = "sweety"
print(name.upper())
# Out:
# SWEETY

# %% [markdown]
# nam = "archana"

# %%
name = "SWEETY"
print(name.lower())
# Out:
# sweety

# %%
name = "SweEtY"
print(name.lower())
# Out:
# sweety

# %%
s = "I like java"
print(s.replace("java","python"))
# Out:
# I like python

# %%
s = " anything something"
print(s.find("something"))
# Out:
# 10

# %%
name = input("Enter the name :")
print("Welcome",name)
# Out:
# Enter the name : sweety
# Welcome sweety

# %%
P = "python"
print(P[::-1])
# Out:
# nohtyp

# %%
name = input("Enter the name")
fee = input("Enter the fee")
print("succesfull",name)
# Out:
# Enter the name archana
# Enter the fee 5k
# succesfull archana

# %%
name = input("Enter the name:")
fee = input("Enter the fee:")
course = input("Enter the course:")
print("succesfull",name)
# Out:
# Enter the name sweety
# Enter the fee 5k
# Enter the course data science
# succesfull sweety

# %%
name = input("Enter the name:")
fee = input("Enter the fee:")
course = input("Enter the course:")
print("succesfull",name)
print("succesfull",fee)
# Out:
# Enter the name: sweety
# Enter the fee: data science
# Enter the course: 5k
# succesfull sweety
# succesfull data science

# %%
p = "python"
print(p[::-2])
# Out:
# nhy

# %%
p = "python"
print(p[::-1])
# Out:
# nohtyp

# %%
p = "python"
print(p[::-3])
# Out:
# nt

# %%
p = "python"
print(p[::1])
# Out:
# python

# %%
name = "sweety"
def greet():
    print("Hello",name)

greet()
# Out:
# Hello sweety

# %%
cause = " died Heart Attack"
def call():
    print("xxx",cause)

call()
# Out:
# xxx  died Heart Attack

# %%
def add(a,b):
    return a+b
print(add (10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
    return a+b+c
print(add (10,20,30))
print(add (10,20))
# Out:
# 60
# 30

# %%
def add(a,b,c=0):
    return a*b*c
print(add (10,20,30))
print(add (10,20))
# Out:
# 6000
# 0
