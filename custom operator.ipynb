# %%
class Parent:
    def fun1(self):
        print("This function is in parent class")
class Child(Parent):
    def fun2(self):
        print("This function is in child class")

object = Parent()
object.fun1()
# Out:
# This function is in parent class

# %%
class Parent:
    def fun1(self):
        print("This function is in parent class")
class Child(Parent):
    def fun2(self):
        print("This function is in child class")
object = Child()
object.fun2()
object.fun1()
# Out:
# This function is in child class
# This function is in parent class

# %%
class Seniors:
    def fun1(self):
       print("she is the senior")
class Junior(Seniors):
    def fun2(self):
       print("she is the junior")

object = Junior()
object.fun1()
object.fun2()
# Out:
# she is the senior
# she is the junior

# %%
class Animal:
    multicellular = True
    eukaryotic = True

    def breathe(self):    
       print("I breathe oxygen")

    def feed(self):
       print("I eat food")

class Herbivorous(Animal):
    def feed(self):
       print("I eat only plants,Iam a vegetarian")
herbi = Herbivorous()
herbi.feed()
herbi.breathe()
# Out:
# I eat only plants,Iam a vegetarian
# I breathe oxygen

# %%
class Grandpa:

    def giver(self):
