# %%
name = "Archana"
age = "19"
print(name)
print(age)
# Out:
# Archana
# 19

# %%
names = "Archana","Sweety","Narukulla"
print(names)
# Out:
# ('Archana', 'Sweety', 'Narukulla')

# %%
print("Hello World")
# Out:
# Hello World

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
a = 10
b = 20
c = 30
print(a+b+c)
# Out:
# 60

# %%
age = int(input("Enter your age : "))
print(age)
# Out:
# Enter your age :  19
# 19

# %%
Fruits = ("Banana", "Mango","Pineapple")
print(Fruits)
# Out:
# ('Banana', 'Mango', 'Pineapple')

# %%
print("Hii! Archana")
# Out:
# Hii! Archana

# %%
city = "Karimnagar"
print(city[1])
# Out:
# a

# %%
city = "Jagitial"
print(city[-4])
# Out:
# t

# %%
name = "Archana"
print(name[1:5])
# Out:
# rcha

# %%
name="sweety"
print(name.lower())
# Out:
# sweety

# %%
college = "alphores womens degree and pg college"
print(college.upper())
# Out:
# ALPHORES WOMENS DEGREE AND PG COLLEGE

# %%
name = input("Enter the name:")
course = input("Enter the course:")
fee = input("Enter the fee:")
print("successfull",name)
# Out:
# Enter the name: Archana
# Enter the course: MStDs
# Enter the fee: 12k
# successfull Archana

# %%
print(10+20)
print("Kavita"+"Yadav")
# Out:
# 30
# KavitaYadav

# %%
print(10000+300000)
print("sweety"+"narukulla")
# Out:
# 310000
# sweetynarukulla

# %%
S = [1,2,3,4]
print(type(S))
# Out:
# <class 'list'>
