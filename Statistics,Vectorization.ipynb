# %%
print("statistics")
# Out:
# statistics

# %%
from scipy import stats
data=(10,20,30,40,50,60)
print(stats.mode(data))
# Out:
# ModeResult(mode=np.int64(10), count=np.int64(1))

# %%
import numpy as np
from scipy import stats
data=(20,25,30,35,40,45,50)
print(np.max(data),np.min(data))
# Out:
# 50 20

# %%
import numpy as np
from scipy import stats
data=([20,30,40,50])
salary=([80000,60000,30000,40000])

print(np.std(data))
# Out:
# 11.180339887498949

# %%
import numpy as np
from scipy import stats
data=([15,23,45,65,67])
print(np.average(data))
# Out:
# 43.0

# %%
import numpy as np
from scipy import stats
marks =[56,78,98,97]
sample = np.random.choice(marks)
print(sample)
# Out:
# 56

# %%
import pandas as pd
marks = [60,70,87,98,78]
sale  = [7000,4000,6000,9000,5000]
for m in marks:
    newmarks = []
    newmarks.append(m*5.0)
for s in sale:
    newsale = []
    newsale.append(s*3.0)
print(newmarks)
print(newsale)
# Out:
# [390.0]
# [15000.0]

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
result = arr *2
print(result)
# Out:
# [ 2  4  6  8 10]

# %%
import numpy as np
a = np.array([1,2,3,4,5])
b = np.array([10,20,30,40,50])
c = a+b
print("Array A:",a)
print("Array B:",b)
print("Addition:",c)
# Out:
# Array A: [1 2 3 4 5]
# Array B: [10 20 30 40 50]
# Addition: [11 22 33 44 55]
